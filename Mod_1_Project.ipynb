# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
filepath= ('/Users/AMINO/Desktop/IMDB_With_Movie_Titles.csv')

# %%
df= pd.read_csv(filepath)

# %%
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df.shape
# Out:
# (146144, 6)

# %%
df.isnull().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
df1 = df[['primary_title', 'genres', 'start_year']]
df1
# Out:
#                                             primary_title  \
# 0                                               Sunghursh
# 1                         One Day Before the Rainy Season
# 2                              The Other Side of the Wind
# 3                                         Sabse Bada Sukh
# 4                                The Wandering Soap Opera
# 5                                             A Thin Life
# 6                                                 Bigfoot
# 7                                         Joe Finds Grace
# 8                                              O Silêncio
# 9                                   Nema aviona za Zagreb
# 10                                            Pál Adrienn
# 11                                   So Much for Justice!
# 12                     Cooper and Hemingway: The True Gen
# 13                           Children of the Green Dragon
# 14                                   T.G.M. - osvoboditel
# ...

# %%
df1.isnull().sum()
# Out:
# primary_title    0
# genres           0
# start_year       0
# dtype: int64

# %%
df1
# Out:
#                                             primary_title  \
# 0                                               Sunghursh
# 1                         One Day Before the Rainy Season
# 2                              The Other Side of the Wind
# 3                                         Sabse Bada Sukh
# 4                                The Wandering Soap Opera
# 5                                             A Thin Life
# 6                                                 Bigfoot
# 7                                         Joe Finds Grace
# 8                                              O Silêncio
# 9                                   Nema aviona za Zagreb
# 10                                            Pál Adrienn
# 11                                   So Much for Justice!
# 12                     Cooper and Hemingway: The True Gen
# 13                           Children of the Green Dragon
# 14                                   T.G.M. - osvoboditel
# ...

# %%
df2= df1.groupby('genres').get_group('Animation').reset_index(drop=True)

# %%
df2
# Out:
#                                          primary_title     genres  start_year
# 0                                        The Slimbones  Animation        2014
# 1                                  The 500 Foot Sister  Animation        2019
# 2                                                Heinz  Animation        2018
# 3                                     La Liga de los 5  Animation        2019
# 4                     A Day With SpongeBob SquarePants  Animation        2011
# 5                                              Reverie  Animation        2015
# 6                                            Xi Bai Po  Animation        2011
# 7                                      The Unbreakable  Animation        2018
# 8                                        Tux and Fanny  Animation        2019
# 9                                             Dog Town  Animation        2019
# 10                            Meet The Space Guardians  Animation        2019
# ...

# %%
df3= df1[df1['genres'].str.contains('Animation')]

# %%
df3
# Out:
#                                             primary_title  \
# 7                                         Joe Finds Grace
# 15                                     The Tragedy of Man
# 20                                             Foodfight!
# 37                 Quantum Quest: A Cassini Space Odyssey
# 47                                        Bunyan and Babe
# 64                                        Gnomeo & Juliet
# 71                                                Tangled
# 104                                           Toy Story 3
# 126                                         Puss in Boots
# 173                                            The Smurfs
# 199                                            The Croods
# 227                                The Hero of Color City
# 235                              Escape from Planet Earth
# 237                             The Legend of Secret Pass
# 252                                       The Illusionist
# ...

# %%
y= df3.groupby("start_year")["genres"].count()
x=df3.groupby("start_year")["genres"].count().index

# %%
figure, ax=plt.subplots(figsize=(15,6))
ax.bar(x,y)
ax.set_title('Number of Animation movies production over previous 10 years')
ax.set_xlabel('Year')
ax.set_ylabel('Animation Movies');

# %%
figure, ax=plt.subplots(figsize=(15,6))
ax.plot(x,y)
ax.set_title('Number of Animation movies production over previous 10 years')
ax.set_xlabel('Year')
ax.set_ylabel('Animation Movies');

# %%
df_RunTime=df[['genres', 'start_year', 'runtime_minutes']]

# %%
df_RunTime
# Out:
#                                genres  start_year  runtime_minutes
# 0                  Action,Crime,Drama        2013            175.0
# 1                     Biography,Drama        2019            114.0
# 2                               Drama        2018            122.0
# 3                        Comedy,Drama        2018              NaN
# 4                Comedy,Drama,Fantasy        2017             80.0
# 5                              Comedy        2018             75.0
# 6                     Horror,Thriller        2017              NaN
# 7          Adventure,Animation,Comedy        2017             83.0
# 8                 Documentary,History        2012              NaN
# 9                           Biography        2012             82.0
# 10                              Drama        2010            136.0
# 11                            History        2010            100.0
# 12                        Documentary        2013            180.0
# ...

# %%
df_RunTime.isnull().sum()
# Out:
# genres                 0
# start_year             0
# runtime_minutes    28503
# dtype: int64

# %%
df_RunTime.dropna(how='any', subset=['runtime_minutes'], inplace=True)
# Out:
# /Users/AMINO/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_RunTime.isnull().sum()
# Out:
# genres             0
# start_year         0
# runtime_minutes    0
# dtype: int64

# %%
df_RunTime.shape
# Out:
# (112233, 3)

# %%
df_RunTime.describe()
# Out:
#           start_year  runtime_minutes
# count  112233.000000    112233.000000
# mean     2014.402101        86.261902
# std         2.639042       167.895938
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2014.000000        87.000000
# 75%      2017.000000        99.000000
# max      2022.000000     51420.000000

# %%
df_RunTime.groupby("start_year")["runtime_minutes"].mean()
# Out:
# start_year
# 2010     85.682222
# 2011     86.610304
# 2012     89.407513
# 2013     85.100166
# 2014     84.584180
# 2015     85.484844
# 2016     84.943409
# 2017     85.665735
# 2018     87.625301
# 2019     90.919693
# 2020     91.296296
# 2021    101.750000
# 2022    109.666667
# Name: runtime_minutes, dtype: float64

# %%
Y= df_RunTime.groupby("start_year")["runtime_minutes"].mean()
X= df_RunTime.groupby("start_year")["runtime_minutes"].mean().index

# %%
figure, ax=plt.subplots(figsize=(15,6))
ax.bar(X,Y)
ax.set_title('Average of Animation Movie Run Time Minutes Over the 10 Years Period')
ax.set_xlabel('Year')
ax.set_ylabel('Run Time Minutes Average');

# %%
filepath2= ('/Users/AMINO/Desktop/tmdb.movies.Pop.csv')
filepath3= ('/Users/AMINO/Desktop/Company_bom.movie_gross.csv')

# %%
df_Pop= pd.read_csv(filepath2)
df_Com= pd.read_csv(filepath3)

# %%
df_Pop.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
df_Com.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df_Mer= pd.merge(df_Pop,df_Com, on='title', how='inner')

# %%
df_Mer.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           1  [14, 12, 16, 10751]  10191                en
# 1           2        [12, 28, 878]  10138                en
# 2           4        [28, 878, 12]  27205                en
# 3           7      [16, 10751, 35]  10193                en
# 4           8      [16, 10751, 35]  20352                en
#
#              original_title  popularity release_date  \
# 0  How to Train Your Dragon      28.734   2010-03-26
# 1                Iron Man 2      28.515   2010-05-07
# 2                 Inception      27.920   2010-07-16
# 3               Toy Story 3      24.445   2010-06-17
# 4             Despicable Me      23.673   2010-07-09
#
#                       title  vote_average  vote_count studio  domestic_gross  \
# 0  How to Train Your Dragon           7.7        7610   P/DW     217600000.0
# 1                Iron Man 2           6.8       12368   Par.     312400000.0
# ...

# %%
df_Mer.shape
# Out:
# (2703, 14)

# %%
df_Mer1 = df_Mer[['genre_ids', 'title', 'popularity', 'vote_average', 'vote_count', 'studio', 'year']]

# %%
df_Mer1.head()
# Out:
#              genre_ids                     title  popularity  vote_average  \
# 0  [14, 12, 16, 10751]  How to Train Your Dragon      28.734           7.7
# 1        [12, 28, 878]                Iron Man 2      28.515           6.8
# 2        [28, 878, 12]                 Inception      27.920           8.3
# 3      [16, 10751, 35]               Toy Story 3      24.445           7.7
# 4      [16, 10751, 35]             Despicable Me      23.673           7.2
#
#    vote_count studio  year
# 0        7610   P/DW  2010
# 1       12368   Par.  2010
# 2       22186     WB  2010
# 3        8340     BV  2010
# 4       10057   Uni.  2010

# %%
df_Mer1.shape
# Out:
# (2703, 7)

# %%
df_Mer1.isnull().sum()
# Out:
# genre_ids       0
# title           0
# popularity      0
# vote_average    0
# vote_count      0
# studio          1
# year            0
# dtype: int64

# %%
df_Mer1.dropna(how='any', subset=['genre_ids'], inplace=True)
# Out:
# /Users/AMINO/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Mer1.isnull().sum()
# Out:
# genre_ids       0
# title           0
# popularity      0
# vote_average    0
# vote_count      0
# studio          1
# year            0
# dtype: int64

# %%
df_Mer2= df_Mer1[df_Mer1['genre_ids'].str.contains('16')]

# %%
df_Mer2.head(157)
# Out:
#                                  genre_ids  \
# 0                      [14, 12, 16, 10751]
# 3                          [16, 10751, 35]
# 4                          [16, 10751, 35]
# 5                 [16, 28, 35, 10751, 878]
# 7                              [16, 10751]
# 19                         [12, 16, 10751]
# 21                 [35, 12, 14, 16, 10751]
# 54                       [12, 14, 16, 878]
# 68                     [16, 12, 10751, 14]
# 98                         [16, 12, 10751]
# 116                    [35, 10751, 16, 12]
# 151             [16, 10751, 35, 12, 10749]
# 199                               [16, 35]
# 276                               [35, 16]
# 289            [16, 12, 35, 10751, 28, 14]
# 300                    [16, 10751, 12, 35]
# 309                            [16, 10751]
# 312                [16, 10751, 12, 35, 14]
# 327                        [16, 35, 10751]
# 328                    [16, 12, 35, 10751]
# 330                [16, 35, 10751, 37, 12]
# ...

# %%
df_Mer2.shape
# Out:
# (157, 7)

# %%
df_Mer2.groupby("studio")["title"].count()
# Out:
# studio
# AZ            1
# BV           31
# CE            1
# CJ            1
# Drft.         1
# EOne          1
# Elev.         3
# FUN           8
# Fathom        1
# Focus         4
# Fox          22
# GK           16
# Good Deed     2
# Imax          1
# Indic.        1
# KKM           1
# LG/S          1
# LGF           6
# MNE           1
# Magn.         1
# ORF           2
# P/DW          7
# Par.          7
# Rela.         1
# SPC           1
# SV            1
# Scre.         1
# Shout!        2
# Sony         13
# Trib.         1
# Uni.         10
# VE            1
# VPD           1
# WB            5
# Name: title, dtype: int64

# %%
X1= df_Mer2.groupby("studio")["title"].count().index
Y1= df_Mer2.groupby("studio")["title"].count()

# %%
figure, ax=plt.subplots(figsize=(24,8))
ax.bar(X1,Y1)
ax.set_title('Animation Movies made by Different Companies Over the 10 Years Period')
ax.set_xlabel('Companies')
ax.set_ylabel('Animation Movies');

# %%
df_Mer2.groupby("studio")["title"].count().nlargest(10)
# Out:
# studio
# BV      31
# Fox     22
# GK      16
# Sony    13
# Uni.    10
# FUN      8
# P/DW     7
# Par.     7
# LGF      6
# WB       5
# Name: title, dtype: int64

# %%
df_Mer2.groupby(["studio", "year"], as_index=False)["title"].count().sort_values(by='year', ascending=False)
# Out:
#        studio  year  title
# 82         WB  2018      1
# 9          BV  2018      3
# 47        LGF  2018      1
# 57       Par.  2018      1
# 61      Scre.  2018      1
# 69       Sony  2018      2
# 19        FUN  2018      1
# 37         GK  2018      4
# 78        VPD  2018      1
# 77         VE  2018      1
# 38  Good Deed  2017      2
# 36         GK  2017      3
# 39       Imax  2017      1
# 42       LG/S  2017      1
# 30        Fox  2017      4
# 46        LGF  2017      2
# 51        ORF  2017      1
# 8          BV  2017      3
# 59        SPC  2017      1
# 18        FUN  2017      3
# 76       Uni.  2017      2
# 15      Elev.  2017      2
# 68       Sony  2017      3
# 20     Fathom  2016      1
# 75       Uni.  2016      3
# 35         GK  2016      2
# 45        LGF  2016      1
# 29        Fox  2016      4
# 13       EOne  2016      1
# 81         WB  2016      1
# ..        ...   ...    ...
# 5          BV  2014      4
# 22      Focus  2014      1
# ...

# %%
##Testing
