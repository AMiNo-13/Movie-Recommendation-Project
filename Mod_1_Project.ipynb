# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
filepath= ('/Users/AMINO/Desktop/IMDB_With_Movie_Titles.csv')

# %%
df= pd.read_csv(filepath)

# %%
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df.shape
# Out:
# (146144, 6)

# %% [markdown]
# Checking for any NaN Values

# %%
df.isnull().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %% [markdown]
# Sorting Useful Columns

# %%
df1 = df[['primary_title', 'genres', 'start_year']]
df1
# Out:
#                                             primary_title  \
# 0                                               Sunghursh
# 1                         One Day Before the Rainy Season
# 2                              The Other Side of the Wind
# 3                                         Sabse Bada Sukh
# 4                                The Wandering Soap Opera
# 5                                             A Thin Life
# 6                                                 Bigfoot
# 7                                         Joe Finds Grace
# 8                                              O Silêncio
# 9                                   Nema aviona za Zagreb
# 10                                            Pál Adrienn
# 11                                   So Much for Justice!
# 12                     Cooper and Hemingway: The True Gen
# 13                           Children of the Green Dragon
# 14                                   T.G.M. - osvoboditel
# ...

# %%
df1.isnull().sum()
# Out:
# primary_title    0
# genres           0
# start_year       0
# dtype: int64

# %%
df1
# Out:
#                                             primary_title  \
# 0                                               Sunghursh
# 1                         One Day Before the Rainy Season
# 2                              The Other Side of the Wind
# 3                                         Sabse Bada Sukh
# 4                                The Wandering Soap Opera
# 5                                             A Thin Life
# 6                                                 Bigfoot
# 7                                         Joe Finds Grace
# 8                                              O Silêncio
# 9                                   Nema aviona za Zagreb
# 10                                            Pál Adrienn
# 11                                   So Much for Justice!
# 12                     Cooper and Hemingway: The True Gen
# 13                           Children of the Green Dragon
# 14                                   T.G.M. - osvoboditel
# ...

# %% [markdown]
# ### Sorting by Animation Genres

# %%
df2= df1.groupby('genres').get_group('Animation').reset_index(drop=True)

# %%
df2
# Out:
#                                          primary_title     genres  start_year
# 0                                        The Slimbones  Animation        2014
# 1                                  The 500 Foot Sister  Animation        2019
# 2                                                Heinz  Animation        2018
# 3                                     La Liga de los 5  Animation        2019
# 4                     A Day With SpongeBob SquarePants  Animation        2011
# 5                                              Reverie  Animation        2015
# 6                                            Xi Bai Po  Animation        2011
# 7                                      The Unbreakable  Animation        2018
# 8                                        Tux and Fanny  Animation        2019
# 9                                             Dog Town  Animation        2019
# 10                            Meet The Space Guardians  Animation        2019
# ...

# %%
df3= df1[df1['genres'].str.contains('Animation')]

# %%
df3
# Out:
#                                             primary_title  \
# 7                                         Joe Finds Grace
# 15                                     The Tragedy of Man
# 20                                             Foodfight!
# 37                 Quantum Quest: A Cassini Space Odyssey
# 47                                        Bunyan and Babe
# 64                                        Gnomeo & Juliet
# 71                                                Tangled
# 104                                           Toy Story 3
# 126                                         Puss in Boots
# 173                                            The Smurfs
# 199                                            The Croods
# 227                                The Hero of Color City
# 235                              Escape from Planet Earth
# 237                             The Legend of Secret Pass
# 252                                       The Illusionist
# ...

# %% [markdown]
# # Groupby Year and Animation Movies

# %%
y= df3.groupby("start_year")["genres"].count()
x=df3.groupby("start_year")["genres"].count().index

# %% [markdown]
# # Ploting The Graph

# %%
figure, ax=plt.subplots(figsize=(15,6))
ax.bar(x,y)
ax.set_title('Number of Animation movies production over previous 10 years')
ax.set_xlabel('Year')
ax.set_ylabel('Animation Movies');

# %%
figure, ax=plt.subplots(figsize=(15,6))
ax.plot(x,y)
ax.set_title('Number of Animation movies production over previous 10 years')
ax.set_xlabel('Year')
ax.set_ylabel('Animation Movies');

# %% [markdown]
# ### Finding average RunTime for each Movie

# %%
df_RunTime=df[['genres', 'start_year', 'runtime_minutes']]

# %%
df_RunTime
# Out:
#                                genres  start_year  runtime_minutes
# 0                  Action,Crime,Drama        2013            175.0
# 1                     Biography,Drama        2019            114.0
# 2                               Drama        2018            122.0
# 3                        Comedy,Drama        2018              NaN
# 4                Comedy,Drama,Fantasy        2017             80.0
# 5                              Comedy        2018             75.0
# 6                     Horror,Thriller        2017              NaN
# 7          Adventure,Animation,Comedy        2017             83.0
# 8                 Documentary,History        2012              NaN
# 9                           Biography        2012             82.0
# 10                              Drama        2010            136.0
# 11                            History        2010            100.0
# 12                        Documentary        2013            180.0
# ...

# %% [markdown]
# ### Removing Null Values

# %%
df_RunTime.isnull().sum()
# Out:
# genres                 0
# start_year             0
# runtime_minutes    28503
# dtype: int64

# %%
df_RunTime.dropna(how='any', subset=['runtime_minutes'], inplace=True)
# Out:
# /Users/AMINO/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_RunTime.isnull().sum()
# Out:
# genres             0
# start_year         0
# runtime_minutes    0
# dtype: int64

# %%
df_RunTime.shape
# Out:
# (112233, 3)

# %% [markdown]
# ### Average RunTime Result

# %%
df_RunTime.describe()
# Out:
#           start_year  runtime_minutes
# count  112233.000000    112233.000000
# mean     2014.402101        86.261902
# std         2.639042       167.895938
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2014.000000        87.000000
# 75%      2017.000000        99.000000
# max      2022.000000     51420.000000

# %% [markdown]
# ### Average RunTime per Year

# %%
df_RunTime.groupby("start_year")["runtime_minutes"].mean()
# Out:
# start_year
# 2010     85.682222
# 2011     86.610304
# 2012     89.407513
# 2013     85.100166
# 2014     84.584180
# 2015     85.484844
# 2016     84.943409
# 2017     85.665735
# 2018     87.625301
# 2019     90.919693
# 2020     91.296296
# 2021    101.750000
# 2022    109.666667
# Name: runtime_minutes, dtype: float64

# %% [markdown]
# ### Ploting and Graphing Average RunTime Per Year

# %%
Y= df_RunTime.groupby("start_year")["runtime_minutes"].mean()
X= df_RunTime.groupby("start_year")["runtime_minutes"].mean().index

# %%
figure, ax=plt.subplots(figsize=(15,6))
ax.bar(X,Y)
ax.set_title('Average of Animation Movie Run Time Minutes Over the 10 Years Period')
ax.set_xlabel('Year')
ax.set_ylabel('Run Time Minutes Average');

# %% [markdown]
# ### Imported 2 New Data Sets

# %%
filepath2= ('/Users/AMINO/Desktop/tmdb.movies.Pop.csv')
filepath3= ('/Users/AMINO/Desktop/Company_bom.movie_gross.csv')

# %%
df_Pop= pd.read_csv(filepath2)
df_Com= pd.read_csv(filepath3)

# %%
df_Pop.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
df_Com.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# ## Merging the 2 Data Sets

# %%
df_Mer= pd.merge(df_Pop,df_Com, on='title', how='inner')

# %%
df_Mer.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           1  [14, 12, 16, 10751]  10191                en
# 1           2        [12, 28, 878]  10138                en
# 2           4        [28, 878, 12]  27205                en
# 3           7      [16, 10751, 35]  10193                en
# 4           8      [16, 10751, 35]  20352                en
#
#              original_title  popularity release_date  \
# 0  How to Train Your Dragon      28.734   2010-03-26
# 1                Iron Man 2      28.515   2010-05-07
# 2                 Inception      27.920   2010-07-16
# 3               Toy Story 3      24.445   2010-06-17
# 4             Despicable Me      23.673   2010-07-09
#
#                       title  vote_average  vote_count studio  domestic_gross  \
# 0  How to Train Your Dragon           7.7        7610   P/DW     217600000.0
# 1                Iron Man 2           6.8       12368   Par.     312400000.0
# ...

# %%
df_Mer.shape
# Out:
# (2703, 14)

# %% [markdown]
# # Filtering Columns

# %%
df_Mer1 = df_Mer[['genre_ids', 'title', 'popularity', 'vote_average', 'vote_count', 'studio', 'year', 'domestic_gross']]

# %%
df_Mer1.head()
# Out:
#              genre_ids                     title  popularity  vote_average  \
# 0  [14, 12, 16, 10751]  How to Train Your Dragon      28.734           7.7
# 1        [12, 28, 878]                Iron Man 2      28.515           6.8
# 2        [28, 878, 12]                 Inception      27.920           8.3
# 3      [16, 10751, 35]               Toy Story 3      24.445           7.7
# 4      [16, 10751, 35]             Despicable Me      23.673           7.2
#
#    vote_count studio  year  domestic_gross
# 0        7610   P/DW  2010     217600000.0
# 1       12368   Par.  2010     312400000.0
# 2       22186     WB  2010     292600000.0
# 3        8340     BV  2010     415000000.0
# 4       10057   Uni.  2010     251500000.0

# %%
df_Mer1.shape
# Out:
# (2703, 8)

# %% [markdown]
# ### Removing the Null Values

# %%
df_Mer1.isnull().sum()
# Out:
# genre_ids          0
# title              0
# popularity         0
# vote_average       0
# vote_count         0
# studio             1
# year               0
# domestic_gross    21
# dtype: int64

# %%
df_Mer1.dropna(how='any', subset=['genre_ids','domestic_gross'], inplace=True)
# Out:
# /Users/AMINO/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Mer1.isnull().sum()
# Out:
# genre_ids         0
# title             0
# popularity        0
# vote_average      0
# vote_count        0
# studio            1
# year              0
# domestic_gross    0
# dtype: int64

# %% [markdown]
# ## Filtering by Animation Movies

# %%
df_Mer2= df_Mer1[df_Mer1['genre_ids'].str.contains('16')]

# %%
df_Mer2.head()
# Out:
#                   genre_ids                     title  popularity  \
# 0       [14, 12, 16, 10751]  How to Train Your Dragon      28.734
# 3           [16, 10751, 35]               Toy Story 3      24.445
# 4           [16, 10751, 35]             Despicable Me      23.673
# 5  [16, 28, 35, 10751, 878]                  Megamind      22.855
# 7               [16, 10751]                   Tangled      21.511
#
#    vote_average  vote_count studio  year  domestic_gross
# 0           7.7        7610   P/DW  2010     217600000.0
# 3           7.7        8340     BV  2010     415000000.0
# 4           7.2       10057   Uni.  2010     251500000.0
# 5           6.8        3635   P/DW  2010     148400000.0
# 7           7.5        6407     BV  2010     200800000.0

# %%
df_Mer2.shape
# Out:
# (156, 8)

# %% [markdown]
# ### Preparing to Plot Highest Domestic Gross Animation Movie

# %%
df_df_Mer2sortedbygross=df_Mer2.sort_values(by="domestic_gross", ascending=False).head(10).reset_index(drop=True)

# %%
df_df_Mer2sortedbygross
# Out:
#              genre_ids                    title  popularity  vote_average  \
# 0             [28, 16]            Black Panther       2.058           5.1
# 1  [28, 12, 16, 10751]            Incredibles 2      36.286           7.6
# 2  [12, 16, 35, 10751]             Finding Dory      15.393           7.0
# 3      [16, 10751, 35]              Toy Story 3      24.445           7.7
# 4      [16, 12, 10751]                   Frozen      26.183           7.3
# 5  [12, 35, 16, 10751]  The Secret Life of Pets       9.909           6.1
# 6      [16, 35, 10751]          Despicable Me 2      19.014           6.9
# 7  [18, 35, 16, 10751]               Inside Out      24.797           8.0
# 8  [16, 12, 10751, 35]                 Zootopia      27.549           7.7
# 9  [10751, 16, 12, 35]                  Minions       9.338           6.4
#
#    vote_count studio  year  domestic_gross
# 0          11     BV  2018     700100000.0
# 1        6354     BV  2018     608600000.0
# ...

# %%
Y=df_df_Mer2sortedbygross.domestic_gross
X=df_df_Mer2sortedbygross.title

# %%
Y
# Out:
# 0    700100000.0
# 1    608600000.0
# 2    486300000.0
# 3    415000000.0
# 4    400700000.0
# 5    368400000.0
# 6    368100000.0
# 7    356500000.0
# 8    341300000.0
# 9    336000000.0
# Name: domestic_gross, dtype: float64

# %%
X
# Out:
# 0              Black Panther
# 1              Incredibles 2
# 2               Finding Dory
# 3                Toy Story 3
# 4                     Frozen
# 5    The Secret Life of Pets
# 6            Despicable Me 2
# 7                 Inside Out
# 8                   Zootopia
# 9                    Minions
# Name: title, dtype: object

# %%
figure, ax=plt.subplots(figsize=(24,8))
ax.bar(X,Y)
ax.set_title('Top Domestic Gross Animated Movie')
ax.set_xlabel('Movies')
ax.set_ylabel('Domestic Gross');

# %% [markdown]
# ### Averaging Yearly Domestic Gross Income

# %%
df_Mer2.groupby("year")["domestic_gross"].descibe()
# Out:
# year
# 2010    1.465299e+08
# 2011    9.954679e+07
# 2012    9.724792e+07
# 2013    1.376155e+08
# 2014    6.002834e+07
# 2015    8.767837e+07
# 2016    1.351104e+08
# 2017    6.116694e+07
# 2018    1.212221e+08
# Name: domestic_gross, dtype: float64

# %%
X5= df_Mer2.groupby("year")["domestic_gross"].mean().index
Y5= df_Mer2.groupby("year")["domestic_gross"].mean()

# %%
figure, ax=plt.subplots(figsize=(24,8))
ax.bar(X5,Y5)
ax.set_title('Average Animation Movie Domestic Gross Per Year')
ax.set_xlabel('Years')
ax.set_ylabel('Average Domestic Gross');

# %% [markdown]
# ## Groupby Animation Studios and their Titles

# %%
df_Mer2.groupby("studio")["title"].count()
# Out:
# studio
# AZ            1
# BV           31
# CE            1
# CJ            1
# Drft.         1
# EOne          1
# Elev.         3
# FUN           8
# Fathom        1
# Focus         4
# Fox          22
# GK           16
# Good Deed     2
# Imax          1
# Indic.        1
# KKM           1
# LG/S          1
# LGF           6
# MNE           1
# Magn.         1
# ORF           2
# P/DW          7
# Par.          7
# Rela.         1
# SPC           1
# SV            1
# Scre.         1
# Shout!        2
# Sony         13
# Trib.         1
# Uni.         10
# VE            1
# VPD           1
# WB            5
# Name: title, dtype: int64

# %% [markdown]
# ## Ploting Animated Movies Release by Studios over the Years

# %%
X1= df_Mer2.groupby("studio")["title"].count(8).index
Y1= df_Mer2.groupby("studio")["title"].count(8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ca6295cebf8> in <module>
# ----> 1 X1= df_Mer2.groupby("studio")["title"].count(8).index
#       2 Y1= df_Mer2.groupby("studio")["title"].count(8)
#
# NameError: name 'df_Mer2' is not defined

# %%
figure, ax=plt.subplots(figsize=(24,8))
ax.bar(X1,Y1)
ax.set_title('Animation Movies made by Different Companies Over the 10 Years Period')
ax.set_xlabel('Companies')
ax.set_ylabel('Animation Movies');

# %% [markdown]
# ### Top 10 Animated Movie Release by Studios

# %%
df_Mer2.groupby("studio")["title"].count().nlargest(10)
# Out:
# studio
# BV      31
# Fox     22
# GK      16
# Sony    13
# Uni.    10
# FUN      8
# P/DW     7
# Par.     7
# LGF      6
# WB       5
# Name: title, dtype: int64

# %%
df_Mer2.groupby(["studio", "year"], as_index=False)["title"].count().sort_values(by='year', ascending=False)
# Out:
#        studio  year  title
# 82         WB  2018      1
# 9          BV  2018      3
# 47        LGF  2018      1
# 57       Par.  2018      1
# 61      Scre.  2018      1
# 69       Sony  2018      2
# 19        FUN  2018      1
# 37         GK  2018      4
# 78        VPD  2018      1
# 77         VE  2018      1
# 38  Good Deed  2017      2
# 36         GK  2017      3
# 39       Imax  2017      1
# 42       LG/S  2017      1
# 30        Fox  2017      4
# 46        LGF  2017      2
# 51        ORF  2017      1
# 8          BV  2017      3
# 59        SPC  2017      1
# 18        FUN  2017      3
# 76       Uni.  2017      2
# 15      Elev.  2017      2
# 68       Sony  2017      3
# 20     Fathom  2016      1
# 75       Uni.  2016      3
# 35         GK  2016      2
# 45        LGF  2016      1
# 29        Fox  2016      4
# 13       EOne  2016      1
# 81         WB  2016      1
# ..        ...   ...    ...
# 5          BV  2014      4
# 22      Focus  2014      1
# ...

# %% [markdown]
# ## Importing Large Data Set from TMDB

# %%
df_MM= pd.read_csv('tmdb_animation.csv', index_col=None, header=0, engine='python')

# %%
df_MM.columns
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df_MM.shape
# Out:
# (10015, 26)

# %% [markdown]
# ### Checking for null Values

# %%
df_MM.isnull().sum()
# Out:
# Unnamed: 0                  0
# adult                      13
# backdrop_path            5985
# belongs_to_collection    8472
# budget                     13
# genres                     13
# homepage                 8068
# id                         13
# imdb_id                  1038
# original_language          13
# original_title             18
# overview                  366
# popularity                 19
# poster_path              3015
# production_companies       19
# production_countries       25
# release_date               64
# revenue                    25
# runtime                   156
# spoken_languages           25
# status                     25
# tagline                  8505
# title                      25
# video                      25
# vote_average               25
# vote_count                 25
# dtype: int64

# %% [markdown]
# ### Filtering Columns

# %%
df_MM1= df_MM[['title','production_companies','budget', 'release_date', 'revenue', 'runtime', 'status', 'vote_average', 'vote_count']]

# %%
df_MM1.head()
# Out:
#                                 title  \
# 0                              Scoob!
# 1                                Cars
# 2                           Frozen II
# 3  Justice League Dark: Apokolips War
# 4                              Onward
#
#                                 production_companies       budget  \
# 0  [{'id': 25120, 'logo_path': '/lqUpBvDLQYG3QaKN...          0.0
# 1  [{'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUH...  120000000.0
# 2  [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...  150000000.0
# 3  [{'id': 2785, 'logo_path': '/l5zW8jjmQOCx2dFmv...          0.0
# 4  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...  200000000.0
#
#   release_date       revenue  runtime    status  vote_average  vote_count
# 0   2020-05-15  0.000000e+00     94.0  Released           8.0       711.0
# 1   2006-06-08  4.619831e+08    117.0  Released           6.8      9381.0
# 2   2019-11-20  1.330765e+09    104.0  Released           7.2      4627.0
# ...

# %% [markdown]
# ### Checking Filtered Columns for Null Values

# %%
df_MM1.isnull().sum()
# Out:
# title                    25
# production_companies     19
# budget                   13
# release_date             64
# revenue                  25
# runtime                 156
# status                   25
# vote_average             25
# vote_count               25
# dtype: int64

# %% [markdown]
# ### Removing Null Values

# %%
df_MM1.dropna(how='any', subset=['budget', 'revenue'], inplace=True)
# Out:
# /Users/AMINO/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_MM1.isnull().sum()
# Out:
# title                     0
# production_companies      0
# budget                    0
# release_date             39
# revenue                   0
# runtime                 131
# status                    0
# vote_average              0
# vote_count                0
# dtype: int64

# %%
Y2= L6.groupby("title")["vote_count"].nlargest(10)
X2= L6.groupby("title")["vote_count"].nlargest(10).index

# %%
figure, ax=plt.subplots(figsize=(24,8))
ax.bar(X2,Y2)
ax.set_title('Animation Movies made by Different Companies Over the 10 Years Period')
ax.set_xlabel('Companies')
ax.set_ylabel('Animation Movies');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-5a2c2edd5d07> in <module>
#       1 figure, ax=plt.subplots(figsize=(24,8))
# ----> 2 ax.bar(X2,Y2)
#       3 ax.set_title('Animation Movies made by Different Companies Over the 10 Years Period')
#       4 ax.set_xlabel('Companies')
#       5 ax.set_ylabel('Animation Movies');
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2346
# ...

# %%
L.shape

# %%
pd.DataFrame(np.random.randn(100, 7))
# Out:
#            0         1         2         3         4         5         6
# 0  -0.153847  0.430023  0.283822  0.726618 -0.047224  0.113847  1.059930
# 1  -1.606712  0.298898 -0.754719  0.990438 -0.773255 -1.351937  0.591690
# 2  -0.163433 -0.031626  1.614016 -0.338493 -1.449140 -0.554186  0.269644
# 3  -1.648522  0.371244 -0.136138  0.999709  0.721275 -0.824359  1.300674
# 4  -0.918454  0.178936  0.602276  1.253141  0.691781  1.291200  0.125667
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.201439  1.088812  0.881713 -1.299894 -0.285602  0.733197  0.355074
# 96  0.338052 -0.241605 -0.397927  2.656672 -0.116481  1.232449 -0.099872
# 97  0.910459 -0.406882  0.697817 -0.266341 -0.518062  1.507413  0.908711
# 98 -0.366662  1.300984  0.355471 -0.488256 -0.482256 -0.797690 -1.210673
# 99  0.020274  0.155790  0.181443  1.985500 -0.393637 -0.118654 -0.840527
#
# [100 rows x 7 columns]

# %%
L=df_MM1[df_MM1.title != '"Eiyuu" Kaitai']

# %%
L3.shape
# Out:
# (9986, 9)

# %%
L6=L5[L5.title != "'Twas the Night Before Bumpy"]

# %%
L6.shape
# Out:
# (9983, 9)

# %%
R=df_MM1[df_MM1.budget != '0.0']

# %%
R.sort_values(by='budget', ascending=False)
# Out:
#                                                   title  \
# 1998  Revolutionary Girl Utena: The Adolescence of U...
# 365                                   The Peanuts Movie
# 2206                                              Night
# 57                           Ice Age: Continental Drift
# 216                               The Road to El Dorado
# ...                                                 ...
# 4877                                           Pandemia
# 5957                                               Lava
# 2127                  One Piece: Strong World Episode 0
# 9264                                  The Ugly Duckling
# 8682                                            The Van
#
#                                    production_companies      budget  \
# 1998  [{'id': 11884, 'logo_path': '/tdt6yTJFV9KIuhpq...    998000.0
# 365   [{'id': 9383, 'logo_path': '/ppeMh4iZJQUMm1nAj...  99000000.0
# 2206  [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...      9577.0
# ...

# %%
R.shape
# Out:
# (741, 9)

# %%
R1=R[R.revenue != '0.0']

# %%
R1.shape
# Out:
# (741, 9)

# %%
dd= R[(R['release_date'] > '2010-01-01') & (R['release_date'] < '2020-02-01')]

# %%
dd.shape
# Out:
# (339, 9)

# %%
ddtop10=dd.sort_values(by='budget', ascending= False).head(10)

# %%
ddtop10
# Out:
#                                             title  \
# 365                             The Peanuts Movie
# 57                     Ice Age: Continental Drift
# 580   Scooby-Doo! and the Curse of the 13th Ghost
# 93                                            Rio
# 8               Spider-Man: Into the Spider-Verse
# 1048                                      Spy Cat
# 4152                                Under the Dog
# 124                            Hotel Transylvania
# 7644                                    Hey Deer!
# 4673                                 Troll Bridge
#
#                                    production_companies      budget  \
# 365   [{'id': 9383, 'logo_path': '/ppeMh4iZJQUMm1nAj...  99000000.0
# 57    [{'id': 9383, 'logo_path': '/ppeMh4iZJQUMm1nAj...  95000000.0
# 580   [{'id': 1353, 'logo_path': '/yXhCcOFK5Fy3ZBQwh...   9260980.0
# 93    [{'id': 9383, 'logo_path': '/ppeMh4iZJQUMm1nAj...  90000000.0
# 8     [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...  90000000.0
# ...

# %%
Y=ddtop10.budget
# Out:
# 365     99000000.0
# 57      95000000.0
# 580      9260980.0
# 93      90000000.0
# 8       90000000.0
# 1048     9000000.0
# 4152      878028.0
# 124     85000000.0
# 7644         845.0
# 4673       82000.0
# Name: budget, dtype: object

# %%
Y3= R1.groupby("title")["budget"].sum().nlargest(10)
X3= R1.groupby("title")["budget"].sum().nlargest(10).index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-d83423724bf9> in <module>
# ----> 1 Y3= R1.groupby("title")["budget"].sum().nlargest(10)
#       2 X3= R1.groupby("title")["budget"].sum().nlargest(10).index
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in nlargest(self, n, keep)
#    3499         dtype: int64
#    3500         """
# -> 3501         return algorithms.SelectNSeries(self, n=n, keep=keep).nlargest()
#    3502
#    3503     def nsmallest(self, n=5, keep="first"):
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/algorithms.py in nlargest(self)
#    1121
#    1122     def nlargest(self):
# -> 1123         return self.compute("nlargest")
#    1124
#    1125     def nsmallest(self):
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/algorithms.py in compute(self, method)
# ...

# %%
figure, ax=plt.subplots(figsize=(24,8))
ax.bar(X3,Y3)
ax.set_title('Animation Movies made by Different Companies Over the 10 Years Period')
ax.set_xlabel('Companies')
ax.set_ylabel('Animation Movies');
